# %% [markdown]
# # فاز دوم — مقایسه مدل‌های کلاسیک (SVM / RF / XGB / KNN / LogReg)
#
# در این نوت‌بوک من مدل‌های کلاسیک مختلف رو روی یک pipeline یکسان آموزش می‌دم و با معیارهای استاندارد مقایسه می‌کنم.
#
# خروجی‌ها:
# - جدول مقایسه در `results/tables/phase2_model_comparison.csv`
# - گزارش کامل در `results/tables/phase2_model_reports.json`
# - نمودارهای Confusion Matrix و ROC برای هر مدل در `results/figures/`
# - Feature Importance برای مدل‌های درختی و ضرایب LogReg

# %%
# !python -m src.training.train_compare_models --out_dir results --save_models

# %%
import pandas as pd
pd.read_csv('results/tables/phase2_model_comparison.csv')

# %% [markdown]
# ## نکته
# اگر در محیط شما `xgboost` نصب نشود (یا با Python نسخه بالا مشکل داشته باشد)، اسکریپت به صورت خودکار XGBoost را رد می‌کند و بقیه مدل‌ها اجرا می‌شوند.
