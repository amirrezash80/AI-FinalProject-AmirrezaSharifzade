# %% [markdown]
# # فاز ۱ — Baseline Logistic Regression (Classic ML)
#
# هدف: یک مدل پایه (Logistic Regression) + ارزیابی اولیه (Confusion Matrix / ROC / metrics).
#
# قبل از اجرا:
# - دیتاست در `data/raw/bank_marketing.csv`
# - اسکریپت مرحله ۴ (preprocess) در پروژه موجود باشد

# %%
import json
from pathlib import Path

# !python -m src.training.train_baseline --out_dir results

report_path = Path('results/tables/baseline_logreg_report.json')
print(report_path.read_text())

# %% [markdown]
# ### خروجی‌ها
# - `results/figures/baseline_logreg_cm_valid.png`
# - `results/figures/baseline_logreg_roc_valid.png`
# - `results/figures/baseline_logreg_cm_test.png`
# - `results/figures/baseline_logreg_roc_test.png`
# - `results/tables/baseline_logreg_report.json`
# - `results/models/baseline_logreg.joblib`
