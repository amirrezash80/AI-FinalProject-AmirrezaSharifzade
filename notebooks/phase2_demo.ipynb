# %% [markdown]
# # فاز دوم — مرحله ۴: Demo و Inference
#
# در این مرحله یک دمو ساده با Streamlit داریم.
#
# اجرا:
# ```bash
# pip install streamlit
# streamlit run app/streamlit_app.py
# ```
#
# همچنین یک CLI برای batch inference روی CSV:
# ```bash
# python -m src.inference.predict_csv --input_csv <path> --output_csv predictions.csv
# ```
